# %% [markdown]
# * NAME: Rishabh Patil
# * SAP: 60009200056
# * BATCH: K2

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("/content/m-s-l.jpg",0)

# %%
print(img.shape)
# Out:
# (403, 612)

# %%
gauss_noise=np.zeros((403,612),dtype=np.uint8)
cv2.randn(gauss_noise,130,20)
gauss_noise=(gauss_noise*0.5).astype(np.uint8)

# %%
gn_img=cv2.add(img,gauss_noise)

# %%
fig=plt.figure(dpi=300)

fig.add_subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis("off")
plt.title("Original")

fig.add_subplot(1,3,2)
plt.imshow(gauss_noise,cmap='gray')
plt.axis("off")
plt.title("Gaussian Noise")

fig.add_subplot(1,3,3)
plt.imshow(gn_img,cmap='gray')
plt.axis("off")
plt.title("Combined")
# Out:
# Text(0.5, 1.0, 'Combined')

# %%
img=gn_img
m, n = img.shape
   
# Develop Averaging filter(3, 3) mask
mask = np.ones([100, 100], dtype = int)
mask = mask / 9
   
# Convolve the 3X3 mask over the image 
img_new = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
         
        img_new[i, j]= temp
          
img_new = img_new.astype(np.uint8)
cv2.imwrite('blurred.tif', img_new)
# Out:
# True

# %%
plt.imshow(img_new,cmap='gray')
plt.axis("off")
plt.title("Combined")
# Out:
# Text(0.5, 1.0, 'Combined')

# %%
import random
import cv2

def add_noise(img):
  
    row , col = img.shape
      
    number_of_pixels = random.randint(300, 10000)
    for i in range(number_of_pixels):
        
        y_coord=random.randint(0, row - 1)
          
        x_coord=random.randint(0, col - 1)
          
        img[y_coord][x_coord] = 255
          
    number_of_pixels = random.randint(300 , 10000)
    for i in range(number_of_pixels):
        
        y_coord=random.randint(0, row - 1)
          
        x_coord=random.randint(0, col - 1)
 
        img[y_coord][x_coord] = 0
          
    return img
  
img = cv2.imread('/content/m-s-l.jpg',
                 cv2.IMREAD_GRAYSCALE)

cv2.imwrite('salt-and-pepper-m-s-l.jpg',
            add_noise(img))
# Out:
# True

# %%
  
img_SP = cv2.imread('/content/salt-and-pepper-m-s-l.jpg',0)
plt.imshow(img_SP,cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 611.5, 402.5, -0.5)

# %%
img_noisy1 = cv2.imread('/content/salt-and-pepper-m-s-l.jpg',0)

m, n = img_noisy1.shape
   
img_new1 = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = [img_noisy1[i-1, j-1],
               img_noisy1[i-1, j],
               img_noisy1[i-1, j + 1],
               img_noisy1[i, j-1],
               img_noisy1[i, j],
               img_noisy1[i, j + 1],
               img_noisy1[i + 1, j-1],
               img_noisy1[i + 1, j],
               img_noisy1[i + 1, j + 1]]
          
        temp = sorted(temp)
        img_new1[i, j]= temp[4]
  
img_new1 = img_new1.astype(np.uint8)
cv2.imwrite('new_median_filtered.png', img_new1)
# Out:
# True

# %%
plt.imshow(img_new1,cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 611.5, 402.5, -0.5)
